# %%
import pandas as pd
# %matplotlib inline

# %%
df = pd.read_csv('cursos-prouni.csv')

df.head()
# Out:
#   uf_busca     cidade_busca  \
# 0       AC       Acrelandia
# 1       AC  Cruzeiro do Sul
# 2       AC  Cruzeiro do Sul
# 3       AC  Cruzeiro do Sul
# 4       AC       Rio Branco
#
#                                    universidade_nome  \
# 0                       Universidade Paulista - UNIP
# 1  Centro Universitário Internacional - Uninter -...
# 2               Faculdade Educacional da Lapa - FAEL
# 3                       Universidade Paulista - UNIP
# 4  Centro Universitário Internacional - Uninter -...
#
#                                 campus_nome           nome         grau  \
# 0                       ACRELANDIA - Centro  Administração  Bacharelado
# 1              PAP CRUZEIRO DO SUL - Centro  Administração  Bacharelado
# 2  AC - CRUZEIRO DO SUL - POLO EAD - CENTRO  Administração  Bacharelado
# 3                  CRUZEIRO DO SUL - Centro  Administração  Bacharelado
# 4                   PAP RIO BRANCO - Bosque  Administração  Bacharelado
#
# ...

# %%
df.shape
# Out:
# (41447, 16)

# %%
df.dtypes
# Out:
# uf_busca                 object
# cidade_busca             object
# universidade_nome        object
# campus_nome              object
# nome                     object
# grau                     object
# turno                    object
# mensalidade             float64
# bolsa_integral_cotas    float64
# bolsa_integral_ampla    float64
# bolsa_parcial_cotas     float64
# bolsa_parcial_ampla     float64
# nota_integral_ampla     float64
# nota_integral_cotas     float64
# nota_parcial_ampla      float64
# nota_parcial_cotas      float64
# dtype: object

# %%
df.describe()
# Out:
#         mensalidade  bolsa_integral_cotas  bolsa_integral_ampla  \
# count  41447.000000          32520.000000          25404.000000
# mean     622.636966              1.535394              2.513541
# std      606.442296              2.191578              3.019549
# min      139.000000              0.000000              1.000000
# 25%      278.000000              0.000000              1.000000
# 50%      393.350000              1.000000              1.000000
# 75%      825.000000              2.000000              3.000000
# max     9999.990000             58.000000             67.000000
#
#        bolsa_parcial_cotas  bolsa_parcial_ampla  nota_integral_ampla  \
# count          8828.000000         13041.000000         32520.000000
# mean              1.873018             8.632544           575.982999
# std               2.336403            18.372991            57.827594
# min               1.000000             1.000000           450.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41447 entries, 0 to 41446
# Data columns (total 16 columns):
# uf_busca                41447 non-null object
# cidade_busca            41447 non-null object
# universidade_nome       41447 non-null object
# campus_nome             41447 non-null object
# nome                    41447 non-null object
# grau                    41447 non-null object
# turno                   41447 non-null object
# mensalidade             41447 non-null float64
# bolsa_integral_cotas    32520 non-null float64
# bolsa_integral_ampla    25404 non-null float64
# bolsa_parcial_cotas     8828 non-null float64
# bolsa_parcial_ampla     13041 non-null float64
# nota_integral_ampla     32520 non-null float64
# nota_integral_cotas     16802 non-null float64
# nota_parcial_ampla      16350 non-null float64
# nota_parcial_cotas      5519 non-null float64
# dtypes: float64(9), object(7)
# memory usage: 5.1+ MB

# %%
# Contagem de cursos por UF
df['uf_busca'].value_counts()
# Out:
# SP    11533
# MG     4175
# PR     3918
# RS     3060
# BA     2505
# SC     2195
# RJ     1442
# GO     1278
# PA     1201
# PE     1148
# MT     1063
# DF     1063
# ES      825
# CE      816
# MS      785
# MA      679
# PB      596
# RO      463
# AM      429
# PI      405
# TO      343
# RN      342
# AL      327
# SE      323
# AP      219
# AC      203
# RR      111
# Name: uf_busca, dtype: int64

# %%
# Curso com maior mensalidade
df[df['mensalidade'] == df['mensalidade'].max()]
# Out:
#       uf_busca  cidade_busca                  universidade_nome  \
# 31987       MS  Campo Grande  Universidade Anhanguera - UNIDERP
#
#                               campus_nome      nome         grau     turno  \
# 31987  CAMPO GRANDE - SEDE - Miguel Couto  Medicina  Bacharelado  Integral
#
#        mensalidade  bolsa_integral_cotas  bolsa_integral_ampla  \
# 31987      9999.99                  15.0                  14.0
#
#        bolsa_parcial_cotas  bolsa_parcial_ampla  nota_integral_ampla  \
# 31987                  NaN                  NaN               740.22
#
#        nota_integral_cotas  nota_parcial_ampla  nota_parcial_cotas
# 31987               726.46                 NaN                 NaN

# %%
# Cursos com menor mensalidade
df[df['mensalidade'] == df['mensalidade'].min()][
    ['mensalidade', 'nome', 'cidade_busca', 'uf_busca']
]
# Out:
#        mensalidade                        nome cidade_busca uf_busca
# 20454        139.0            Gestão Ambiental     Santarem       PA
# 22934        139.0  Gestão de Recursos Humanos     Brasilia       DF
# 39118        139.0              Serviço Social      Vitoria       ES

# %%
df.groupby('uf_busca')['mensalidade'].max()
# Out:
# uf_busca
# AC    9674.34
# AL    7290.00
# AM    2127.05
# AP    3607.62
# BA    9048.00
# CE    9836.40
# DF    6757.92
# ES    6022.28
# GO    6484.47
# MA    8281.38
# MG    9350.00
# MS    9999.99
# MT    9208.00
# PA    8508.54
# PB    8350.00
# PE    7250.00
# PI    8402.00
# PR    8466.72
# RJ    9023.07
# RN    6505.09
# RO    6909.97
# RR    1463.05
# RS    8329.95
# SC    6922.15
# SE    6490.00
# SP    9715.61
# TO    7800.00
# Name: mensalidade, dtype: float64

# %%
df.loc[df.groupby('uf_busca')['mensalidade'].idxmax()][
    ['uf_busca', 'cidade_busca', 'nome', 'mensalidade']
]
# Out:
#       uf_busca      cidade_busca             nome  mensalidade
# 31940       AC        Rio Branco         Medicina      9674.34
# 31941       AL            Maceio         Medicina      7290.00
# 32962       AM            Manaus      Odontologia      2127.05
# 32966       AP            Macapa      Odontologia      3607.62
# 31945       BA  Lauro de Freitas         Medicina      9048.00
# 12916       CE           Crateus       Enfermagem      9836.40
# 31950       DF          Brasilia         Medicina      6757.92
# 31952       ES          Colatina         Medicina      6022.28
# 31957       GO           Goiania         Medicina      6484.47
# 31959       MA        Imperatriz         Medicina      8281.38
# 31983       MG  Sao Joao Del Rei         Medicina      9350.00
# 31987       MS      Campo Grande         Medicina      9999.99
# 31988       MT            Cuiaba         Medicina      9208.00
# 31990       PA             Belem         Medicina      8508.54
# ...

# %%
# Mensalidade entre 500 e 1000

df[(df['mensalidade'] > 500) & (df['mensalidade'] < 1000)][
    ['uf_busca', 'cidade_busca', 'nome', 'mensalidade']
]
# Out:
#       uf_busca            cidade_busca                            nome  \
# 5           AC              Rio Branco                   Administração
# 9           AC              Rio Branco                   Administração
# 10          AC              Rio Branco                   Administração
# 13          AL               Arapiraca                   Administração
# 18          AL                  Maceio                   Administração
# 19          AL                  Maceio                   Administração
# 20          AL                  Maceio                   Administração
# 23          AL                  Maceio                   Administração
# 24          AL                  Maceio                   Administração
# 25          AL                  Maceio                   Administração
# 27          AL                  Maceio                   Administração
# 34          AM                  Manaus                   Administração
# ...

# %%
# 5 maiores mensalidades

df.nlargest(5, "mensalidade")
# Out:
#       uf_busca  cidade_busca                          universidade_nome  \
# 31987       MS  Campo Grande          Universidade Anhanguera - UNIDERP
# 12916       CE       Crateus          Faculdade Princesa do Oeste - FPO
# 32058       SP     Sao Paulo  Universidade Cidade de São Paulo - UNICID
# 37058       CE       Crateus          Faculdade Princesa do Oeste - FPO
# 31940       AC    Rio Branco        Faculdade Barão do Rio Branco - FAB
#
#                                              campus_nome        nome  \
# 31987                 CAMPO GRANDE - SEDE - Miguel Couto    Medicina
# 12916                         UNIDADE SEDE - São Vicente  Enfermagem
# 32058  UNIVERSIDADE CIDADE DE SÃO PAULO - UNICID - SE...    Medicina
# 37058                         UNIDADE SEDE - São Vicente  Psicologia
# 31940  CAMPUS  - RIO BRANCO - JARDIM EUROPA II - Jard...    Medicina
#
#               grau     turno  mensalidade  bolsa_integral_cotas  \
# ...

# %%
# 5 maiores mensalidades

df.nsmallest(5, "mensalidade")["mensalidade"]
# Out:
# 20454    139.0
# 22934    139.0
# 39118    139.0
# 30989    144.0
# 20836    149.0
# Name: mensalidade, dtype: float64
